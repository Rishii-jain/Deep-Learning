# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishii-jain/Deep-Learning/blob/main/RNN_IntegerCoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding, Flatten

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from keras.utils import pad_sequences

# %%
X_train = pad_sequences(X_train, maxlen = 50, padding = 'post')
X_test =  pad_sequences(X_test, maxlen = 50, padding = 'post')

# %%
model = Sequential()

model.add(SimpleRNN(32, input_shape = (50, 1), return_sequences = False))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 5, validation_data = (X_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.5028 - loss: 0.6976 - val_accuracy: 0.5078 - val_loss: 0.6937
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.5100 - loss: 0.6925 - val_accuracy: 0.5052 - val_loss: 0.6934
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5029 - loss: 0.6932 - val_accuracy: 0.5044 - val_loss: 0.6945
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5106 - loss: 0.6928 - val_accuracy: 0.5020 - val_loss: 0.6938
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.4960 - loss: 0.6933 - val_accuracy: 0.5064 - val_loss: 0.6946
